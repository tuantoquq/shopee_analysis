# %%
import json
import pandas as pd

df = pd.read_csv('./data.csv')

# %%
df
# Out:
#            itemid     shopid  userid  price_max_before_discount  \
# 0      1417823595   48865237       0                  900000000
# 1     10958521551  101281841       0                         -1
# 2     11848818786  466736605       0                         -1
# 3      7453772621   63082962       0                         -1
# 4      2316916236  109787200       0                         -1
# ...           ...        ...     ...                        ...
# 8033   4834669559  263481983       0                         -1
# 8034    720677722   10931069       0                         -1
# 8035   1784828154   39317517       0                         -1
# 8036   4732390034   33931138       0                22000000000
# 8037   6249913180  303263608       0                41500000000
#
#       has_lowest_price_guarantee  price_before_discount  \
# 0                          False              500000000
# 1                          False                      0
# ...
